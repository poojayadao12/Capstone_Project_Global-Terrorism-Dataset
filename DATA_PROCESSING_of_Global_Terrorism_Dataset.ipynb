# %% [markdown]
# <a href="https://colab.research.google.com/github/poojayadao12/Capstone_Project_Global-Terrorism-Dataset/blob/main/DATA_PROCESSING_of_Global_Terrorism_Dataset.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
#  **GLOBAL TERRORISM ANALYSIS
#  DATA PREPROCESSING**

# %% [markdown]
# Importing necessary libraries

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import matplotlib as mat
pd.options.mode.chained_assignment = None
import plotly.express as px
import seaborn as sns
from scipy.stats import mode
import csv
import ast
# %matplotlib inline

# %% [markdown]
# Connecting colab to google drive

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
#  importing data from google drive

# %%
file_path = '/content/drive/MyDrive/GlobalTerrorism.csv'
df=pd.read_csv(file_path, encoding='ISO-8859-1' )
# Out:
# <ipython-input-3-2b88956fc12c>:2: DtypeWarning: Columns (4,6,31,33,61,62,63,76,79,90,92,94,96,114,115,121) have mixed types. Specify dtype option on import or set low_memory=False.
#   df=pd.read_csv(file_path, encoding='ISO-8859-1' )

# %% [markdown]
# Initial layout of the data

# %%
df.head(10)
# Out:
#         eventid  iyear  imonth  iday approxdate  extended resolution  country  \
# 0  197000000001   1970       7     2        NaN         0        NaN       58
# 1  197000000002   1970       0     0        NaN         0        NaN      130
# 2  197001000001   1970       1     0        NaN         0        NaN      160
# 3  197001000002   1970       1     0        NaN         0        NaN       78
# 4  197001000003   1970       1     0        NaN         0        NaN      101
# 5  197001010002   1970       1     1        NaN         0        NaN      217
# 6  197001020001   1970       1     2        NaN         0        NaN      218
# 7  197001020002   1970       1     2        NaN         0        NaN      217
# 8  197001020003   1970       1     2        NaN         0        NaN      217
# 9  197001030001   1970       1     3        NaN         0        NaN      217
#
#           country_txt  region  ...  \
# 0  Dominican Republic       2  ...
# 1              Mexico       1  ...
# 2         Philippines       5  ...
# 3              Greece       8  ...
# 4               Japan       4  ...
# 5       United States       1  ...
# 6             Uruguay       3  ...
# 7       United States       1  ...
# 8       United States       1  ...
# 9       United States       1  ...
#
#                                             addnotes  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
# 5  The Cairo Chief of Police, William Petersen, r...
# 6                                                NaN
# 7  Damages were estimated to be between $20,000-$...
# 8  The New Years Gang issue a communiqué to a loc...
# 9  Karl Armstrong's girlfriend, Lynn Schultz, dro...
#
#                                               scite1  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
# 5  "Police Chief Quits," Washington Post, January...
# 6                                                NaN
# 7  Committee on Government Operations United Stat...
# 8  Tom Bates, "Rads: The 1970 Bombing of the Army...
# 9  Committee on Government Operations United Stat...
#
#                                               scite2  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
# 5  "Cairo Police Chief Quits; Decries Local 'Mili...
# 6                                                NaN
# 7  Christopher Hewitt, "Political Violence and Te...
# 8  David Newman, Sandra Sutherland, and Jon Stewa...
# 9  Tom Bates, "Rads: The 1970 Bombing of the Army...
#
#                                               scite3        dbsource  INT_LOG  \
# 0                                                NaN            PGIS        0
# 1                                                NaN            PGIS        0
# 2                                                NaN            PGIS       -9
# 3                                                NaN            PGIS       -9
# 4                                                NaN            PGIS       -9
# 5  Christopher Hewitt, "Political Violence and Te...  Hewitt Project       -9
# 6                                                NaN            PGIS        0
# 7                                                NaN  Hewitt Project       -9
# 8  The Wisconsin Cartographers' Guild, "Wisconsin...  Hewitt Project        0
# 9  David Newman, Sandra Sutherland, and Jon Stewa...  Hewitt Project        0
#
#    INT_IDEO INT_MISC INT_ANY  related
# 0         0        0       0      NaN
# 1         1        1       1      NaN
# 2        -9        1       1      NaN
# 3        -9        1       1      NaN
# 4        -9        1       1      NaN
# 5        -9        0      -9      NaN
# 6         0        0       0      NaN
# 7        -9        0      -9      NaN
# 8         0        0       0      NaN
# 9         0        0       0      NaN
#
# [10 rows x 135 columns]

# %%
print ('dataframe shape: ', df.shape)
# Out:
# dataframe shape:  (181691, 135)

# %%
print ('Existance of nul values', df.isnull().values.any())
print ('Total number of null values in entire dataframe: ', df.isnull().sum().sum())
# Out:
# Existance of nul values True
# Total number of null values in entire dataframe:  13853997

# %% [markdown]
# Filtering out of the columns we need

# %%
df = df[['eventid','iyear','imonth','country_txt','region_txt','city','attacktype1_txt','targtype1_txt','natlty1_txt','nkill','claimed','weaptype1_txt','weapdetail','nwound','nkillter','gname','ishostkid','propextent_txt','provstate','ransom']].copy()

# %% [markdown]
# Renaming certain columns to better identifiable names

# %%
df.rename(columns = 
                  {'eventid':'id','iyear':'year', 
                   'imonth':'month',
                   'iday':'day',
                   'country_txt' : 'Country',
                   'region_txt' : 'region',
                   'crit1' : 'crit',
                   'attacktype1_txt' : 'attacktype',
                   'targtype1_txt' : 'targettype',
                   'natlty1_txt' : 'nationalityofvic',
                   'gname' : 'organisation',
                   'claimed' : 'claimedresp',
                   'weaptype1_txt' : 'weapontype',
                   'nkill' : 'nkilled',
                   'nkillter' : 'nkillonlyter',
                   'nwound' : 'nwounded',
                   'propextent_txt' : 'propdamageextent',
                   'ishostkid' : 'victimkidnapped',
                   'ransom' : 'ransomdemanded',
                   'provstate' : 'state'
                   }, inplace = True)

# %% [markdown]
# looking for columns name

# %%
df.columns
# Out:
# Index(['id', 'year', 'month', 'Country', 'region', 'city', 'attacktype',
#        'targettype', 'nationalityofvic', 'nkilled', 'claimedresp',
#        'weapontype', 'weapdetail', 'nwounded', 'nkillonlyter', 'organisation',
#        'victimkidnapped', 'propdamageextent', 'state', 'ransomdemanded'],
#       dtype='object')

# %%
print ('Number of null values in named col of dataframe: ', df.isnull().sum())
# Out:
# Number of null values in named col of dataframe:  id                       0
# year                     0
# month                    0
# Country                  0
# region                   0
# city                   434
# attacktype               0
# targettype               0
# nationalityofvic      1559
# nkilled              10313
# claimedresp          66120
# weapontype               0
# weapdetail           67670
# nwounded             16311
# nkillonlyter         66958
# organisation             0
# victimkidnapped        178
# propdamageextent    117626
# state                  421
# ransomdemanded      104310
# dtype: int64

# %%
#Add column ncasualties (Number of Dead/Injured people) by adding Nkill and Nwound
df['ncasualties'] = df['nkilled'] + df['nwounded']

# %%
# Limit long strings
df['weapontype'] = df['weapontype'].replace(u'Vehicle (not to include vehicle-borne explosives, i.e., car or truck bombs)', 'Vehicle')


df['propdamageextent'] = df['propdamageextent'].replace('Minor (likely < $1 million)', 'Minor')
df['propdamageextent'] = df['propdamageextent'].replace('Major (likely > 1 billion)', 'Major')
df['propdamageextent'] = df['propdamageextent'].replace('Catastrophic (likely > $1 billion)', 'Catastrophic')

# %% [markdown]
# ..........

# %% [markdown]
# ..........

# %% [markdown]
# **Glimpse of the final preprocessed data**

# %%
df.head(10)
# Out:
#              id  year  month             Country                       region  \
# 0  197000000001  1970      7  Dominican Republic  Central America & Caribbean
# 1  197000000002  1970      0              Mexico                North America
# 2  197001000001  1970      1         Philippines               Southeast Asia
# 3  197001000002  1970      1              Greece               Western Europe
# 4  197001000003  1970      1               Japan                    East Asia
# 5  197001010002  1970      1       United States                North America
# 6  197001020001  1970      1             Uruguay                South America
# 7  197001020002  1970      1       United States                North America
# 8  197001020003  1970      1       United States                North America
# 9  197001030001  1970      1       United States                North America
#
#             city                      attacktype                   targettype  \
# 0  Santo Domingo                   Assassination  Private Citizens & Property
# 1    Mexico city     Hostage Taking (Kidnapping)      Government (Diplomatic)
# 2        Unknown                   Assassination          Journalists & Media
# 3         Athens               Bombing/Explosion      Government (Diplomatic)
# 4        Fukouka  Facility/Infrastructure Attack      Government (Diplomatic)
# 5          Cairo                   Armed Assault                       Police
# 6     Montevideo                   Assassination                       Police
# 7        Oakland               Bombing/Explosion                    Utilities
# 8        Madison  Facility/Infrastructure Attack                     Military
# 9        Madison  Facility/Infrastructure Attack         Government (General)
#
#      nationalityofvic  nkilled  ...  weapontype  \
# 0  Dominican Republic      1.0  ...     Unknown
# 1             Belgium      0.0  ...     Unknown
# 2       United States      1.0  ...     Unknown
# 3       United States      NaN  ...  Explosives
# 4       United States      NaN  ...  Incendiary
# 5       United States      0.0  ...    Firearms
# 6             Uruguay      0.0  ...    Firearms
# 7       United States      0.0  ...  Explosives
# 8       United States      0.0  ...  Incendiary
# 9       United States      0.0  ...  Incendiary
#
#                                           weapdetail nwounded  nkillonlyter  \
# 0                                                NaN      0.0           NaN
# 1                                                NaN      0.0           NaN
# 2                                                NaN      0.0           NaN
# 3                                          Explosive      NaN           NaN
# 4                                         Incendiary      NaN           NaN
# 5                       Several gunshots were fired.      0.0           0.0
# 6                                  Automatic firearm      0.0           NaN
# 7                                                NaN      0.0           0.0
# 8                    Firebomb consisting of gasoline      0.0           0.0
# 9  Poured gasoline on the floor and lit it with a...      0.0           0.0
#
#                          organisation victimkidnapped  propdamageextent  \
# 0                              MANO-D             0.0               NaN
# 1  23rd of September Communist League             1.0               NaN
# 2                             Unknown             0.0               NaN
# 3                             Unknown             0.0               NaN
# 4                             Unknown             0.0               NaN
# 5                  Black Nationalists             0.0             Minor
# 6                 Tupamaros (Uruguay)             0.0               NaN
# 7                             Unknown             0.0             Minor
# 8                     New Year's Gang             0.0             Minor
# 9                     New Year's Gang             0.0             Minor
#
#         state ransomdemanded  ncasualties
# 0         NaN            0.0          1.0
# 1     Federal            1.0          0.0
# 2      Tarlac            0.0          1.0
# 3      Attica            0.0          NaN
# 4     Fukouka            0.0          NaN
# 5    Illinois            0.0          0.0
# 6  Montevideo            0.0          0.0
# 7  California            0.0          0.0
# 8   Wisconsin            0.0          0.0
# 9   Wisconsin            0.0          0.0
#
# [10 rows x 21 columns]

# %%
print ('final dataframe shape: ', df.shape)
# Out:
# final dataframe shape:  (181691, 21)

# %%
#Check for general information
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 181691 entries, 0 to 181690
# Data columns (total 21 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   id                181691 non-null  int64
#  1   year              181691 non-null  int64
#  2   month             181691 non-null  int64
#  3   Country           181691 non-null  object
#  4   region            181691 non-null  object
#  5   city              181257 non-null  object
#  6   attacktype        181691 non-null  object
#  7   targettype        181691 non-null  object
#  8   nationalityofvic  180132 non-null  object
#  9   nkilled           171378 non-null  float64
#  10  claimedresp       115571 non-null  float64
#  11  weapontype        181691 non-null  object
#  12  weapdetail        114021 non-null  object
#  13  nwounded          165380 non-null  float64
#  14  nkillonlyter      114733 non-null  float64
#  15  organisation      181691 non-null  object
#  16  victimkidnapped   181513 non-null  float64
#  17  propdamageextent  64065 non-null   object
#  18  state             181270 non-null  object
#  19  ransomdemanded    77381 non-null   float64
#  20  ncasualties       164817 non-null  float64
# dtypes: float64(7), int64(3), object(11)
# memory usage: 29.1+ MB

# %%
# checking for describe
df[['nkilled', 'nkillonlyter', 'nwounded', 'propdamageextent', 
        'ncasualties']].describe().transpose()
# Out:
#                  count      mean        std  min  25%  50%  75%     max
# nkilled       171378.0  2.403272  11.545741  0.0  0.0  0.0  2.0  1570.0
# nkillonlyter  114733.0  0.508058   4.199937  0.0  0.0  0.0  0.0   500.0
# nwounded      165380.0  3.167668  35.949392  0.0  0.0  0.0  2.0  8191.0
# ncasualties   164817.0  5.296128  42.069023  0.0  0.0  1.0  4.0  9574.0

# %% [markdown]
# ..........
#
#
# **End of data preprocessing**
